# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Cargar el archivo CSV
archivo_csv = '/content/kc_house_data.csv'  # La ruta de tu archivo CSV
datos = pd.read_csv(archivo_csv)

# %%
# Extraer dos columnas de datos
columna1 = 'price'  # Precio
columna2 = 'sqft_living'  #  área habitable de una casa, expresada en pies cuadrados
datos_a_usar = datos[[columna1, columna2]]
print(datos_a_usar)
# Out:
#           price  sqft_living
# 0      221900.0         1180
# 1      538000.0         2570
# 2      180000.0          770
# 3      604000.0         1960
# 4      510000.0         1680
# ...         ...          ...
# 21608  360000.0         1530
# 21609  400000.0         2310
# 21610  402101.0         1020
# 21611  400000.0         1600
# 21612  325000.0         1020
#
# [21613 rows x 2 columns]

# %%
# Aplicar el algoritmo K-Means
numero_clusters = 3  # Puedes ajustar este valor
kmeans = KMeans(n_clusters=numero_clusters)
kmeans.fit(datos_a_usar)
etiquetas = kmeans.predict(datos_a_usar)
centroides = kmeans.cluster_centers_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Visualizar los resultados
plt.scatter(datos_a_usar[columna1], datos_a_usar[columna2], c=etiquetas, cmap='viridis')
plt.scatter(centroides[:, 0], centroides[:, 1], marker='X', s=100, c='red')
plt.xlabel(columna1)
plt.ylabel(columna2)
plt.title('Resultados del algoritmo K-Means')
plt.show()
